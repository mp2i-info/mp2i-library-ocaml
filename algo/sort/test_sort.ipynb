# %%
#use "sort.ml"
# Out:
# val swap : 'a array -> int -> int -> unit = <fun>
# val sort_bubble : 'a array -> unit = <fun>

# %%
let t = [|4; 1; -5; 0; 7|]
# Out:
# val t : int array = [|4; 1; -5; 0; 7|]

# %%
sort_bubble t
# Out:
# - : unit = ()

# %%
t
# Out:
# - : int array = [|-5; 0; 1; 4; 7|]
